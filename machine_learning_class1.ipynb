# %% [markdown]
# <a href="https://colab.research.google.com/github/Mharis55/Data_Analytics_Bootcamp_2024/blob/main/machine_learning_class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'/content/udemy_output_All_Finance__Accounting_p1_p626.csv')

# %%
#check for null values
df.isnull().sum()
# Out:
# id                                 0
# title                              0
# url                                0
# is_paid                            0
# num_subscribers                    0
# avg_rating                         0
# avg_rating_recent                  0
# rating                             0
# num_reviews                        0
# is_wishlisted                      0
# num_published_lectures             0
# num_published_practice_tests       0
# created                            0
# published_time                     0
# discount_price__amount          1403
# discount_price__currency        1403
# discount_price__price_string    1403
# price_detail__amount             497
# price_detail__currency           497
# price_detail__price_string       497
# dtype: int64

# %%
import missingno as mn

# %%
mn.heatmap(df)
# Out:
# <Axes: >

# %%
df[['discount_price__amount']].mean()
# Out:
# discount_price__amount    493.943794
# dtype: float64

# %%
df['discount_price__amount'].fillna(0, inplace = True)

# %%
df.drop('price_detail__price_string', axis = 1, inplace = True)

# %%
df.drop('discount_price__price_string', axis = 1, inplace = True)

# %%
df['discount_price__currency'].mode()
# Out:
# 0    INR
# Name: discount_price__currency, dtype: object

# %%
df['discount_price__currency'].fillna("INR", inplace=True)

# %%
df['price_detail__amount'].mode()
# Out:
# 0    8640.0
# Name: price_detail__amount, dtype: float64

# %%
df['discount_price__currency'].fillna(8640, inplace=True)

# %%
df['price_detail__currency'].mode()
# Out:
# 0    INR
# Name: price_detail__currency, dtype: object

# %%
df['discount_price__currency'].fillna("INR", inplace=True)

# %%
df.isnull().sum()
# Out:
# id                                0
# title                             0
# url                               0
# is_paid                           0
# num_subscribers                   0
# avg_rating                        0
# avg_rating_recent                 0
# rating                            0
# num_reviews                       0
# is_wishlisted                     0
# num_published_lectures            0
# num_published_practice_tests      0
# created                           0
# published_time                    0
# discount_price__amount            0
# discount_price__currency          0
# price_detail__amount            497
# price_detail__currency          497
# dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
categorical_colums = df.select_dtypes(include=['object']).columns.tolist()
categorical_colums
# Out:
# ['title',
#  'url',
#  'created',
#  'published_time',
#  'discount_price__currency',
#  'price_detail__currency']

# %%
encoder = OneHotEncoder(sparse_output=False)

# %%
one_hot_encoded_df = encoder.fit_transform(df[categorical_colums])
